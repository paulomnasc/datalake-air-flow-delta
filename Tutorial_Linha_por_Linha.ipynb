# %% [markdown]
# # 📚 Tutorial Linha-por-Linha: meu_validador.py
# ## Analise cada linha do código original de forma interativa
#
# Este notebook exibe **exatamente as linhas do arquivo original** com explicações detalhadas.
#
# > **Como usar**: Execute cada célula sequencialmente com ▶️ para ver a linha + explicação

# %% [markdown]
# ---
# ## 📦 SEÇÃO 1: IMPORTAÇÕES (Linhas 12-16)
#
# As primeiras linhas que trazem as dependências necessárias.

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHA 12                                                           ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHA 12 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  from lib.medallion_pipeline_v2 import RawToMedallionPipeline")
print()
print("O QUE FAZ:")
print("  ✓ Importa a classe RawToMedallionPipeline")
print("  ✓ Esta classe será superclasse de MeuValidador")
print("  ✓ Fornece acesso automático a S3, bucket, tmpdir")
print()
print("VISUALIZAÇÃO:")
print()
print("  RawToMedallionPipeline (classe base)")
print("  └─ Fornece:")
print("     • self.hook      → Conexão com S3")
print("     • self.bucket    → Nome do bucket")
print("     • self.tmpdir    → Diretório temporário")
print("     • Métodos de ciclo de vida (hooks)")
print()
print("BENEFÍCIO:")
print("  ✅ Reutilização de código")
print("  ✅ Sem necessidade de reimplementar S3")
print("  ✅ Sincronização automática garantida")
# Out:
# ...
# 📍 LINHA 12 DO ARQUIVO meu_validador.py
# ...
#
# CÓDIGO ORIGINAL:
#   from lib.medallion_pipeline_v2 import RawToMedallionPipeline
#
# O QUE FAZ:
#   ✓ Importa a classe RawToMedallionPipeline
#   ✓ Esta classe será superclasse de MeuValidador
#   ✓ Fornece acesso automático a S3, bucket, tmpdir
#
# VISUALIZAÇÃO:
#
#   RawToMedallionPipeline (classe base)
#   └─ Fornece:
#      • self.hook      → Conexão com S3
#      • self.bucket    → Nome do bucket
#      • self.tmpdir    → Diretório temporário
#      • Métodos de ciclo de vida (hooks)
#
# BENEFÍCIO:
#   ✅ Reutilização de código
#   ✅ Sem necessidade de reimplementar S3
#   ✅ Sincronização automática garantida

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHA 13                                                           ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHA 13 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  import pandas as pd")
print()
print("O QUE FAZ:")
print("  ✓ Importa a biblioteca pandas")
print("  ✓ Renomeia como 'pd' para facilitar uso")
print("  ✓ Pandas trabalha com DataFrames (tabelas de dados)")
print()
print("MÉTODOS QUE USAREMOS:")
print("  • pd.read_parquet()  → Ler arquivo Parquet")
print("  • df.to_parquet()    → Salvar como Parquet")
print("  • df.columns         → Acessar nomes de colunas")
print("  • df.loc[]           → Indexação por localização")
print("  • df.drop()          → Remover colunas")
print()
print("EXEMPLO:")
print("  df = pd.read_parquet('dados.parquet')")
print("  # df agora é um DataFrame com os dados em memória")
# Out:
# ...
# 📍 LINHA 13 DO ARQUIVO meu_validador.py
# ...
#
# CÓDIGO ORIGINAL:
#   import pandas as pd
#
# O QUE FAZ:
#   ✓ Importa a biblioteca pandas
#   ✓ Renomeia como 'pd' para facilitar uso
#   ✓ Pandas trabalha com DataFrames (tabelas de dados)
#
# MÉTODOS QUE USAREMOS:
#   • pd.read_parquet()  → Ler arquivo Parquet
#   • df.to_parquet()    → Salvar como Parquet
#   • df.columns         → Acessar nomes de colunas
#   • df.loc[]           → Indexação por localização
#   • df.drop()          → Remover colunas
#
# EXEMPLO:
#   df = pd.read_parquet('dados.parquet')
#   # df agora é um DataFrame com os dados em memória

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHA 14                                                           ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHA 14 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  import logging")
print()
print("O QUE FAZ:")
print("  ✓ Importa módulo de logging do Python")
print("  ✓ Permite registrar mensagens durante execução")
print("  ✓ Essencial para rastreamento e debugging")
print()
print("NÍVEIS DE LOG:")
print("  • DEBUG    → Detalhes para debug")
print("  • INFO     → Informações (ℹ️  tudo OK)")
print("  • WARNING  → Aviso (⚠️  atenção)")
print("  • ERROR    → Erro (❌ problema)")
print("  • CRITICAL → Crítico (🔴 parou)")
print()
print("EXEMPLO:")
print("  log.info('Processamento iniciado')")
print("  log.warning('Campo vazio encontrado')")
print("  log.error('Erro ao ler arquivo')")

# %% [markdown]
# ---
# ## 🏗️ SEÇÃO 2: DEFINIÇÃO DA CLASSE (Linhas 19-29)
#
# A criação da classe que herda de RawToMedallionPipeline.

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHA 19                                                           ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHA 19 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  class MeuValidador(RawToMedallionPipeline):")
print()
print("COMPONENTES:")
print("  • class                    → Define uma classe")
print("  • MeuValidador             → Nome da classe")
print("  • (RawToMedallionPipeline) → Classe pai (herança)")
print()
print("HERANÇA:")
print()
print("  RawToMedallionPipeline (pai)")
print("           ↑")
print("           │")
print("      MeuValidador (filho)")
print()
print("  MeuValidador herda:")
print("  ✓ Todos os atributos da classe pai")
print("  ✓ Todos os métodos da classe pai")
print("  ✓ Pode sobrescrever (override) métodos")
print()
print("VANTAGENS:")
print("  ✅ Reutilização de código testado")
print("  ✅ Interface padronizada")
print("  ✅ Fácil manutenção")
print("  ✅ Escalabilidade")

# %% [markdown]
# ---
# ## 🎯 SEÇÃO 3: MÉTODO PRINCIPAL (Linhas 31-70)
#
# O método que é chamado automaticamente pelo pipeline.

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHA 30                                                           ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHA 30 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  def silver_layer_transform(self, silver_key: str) -> str:")
print()
print("ANATOMIA:")
print("  def                      → Define um método")
print("  silver_layer_transform   → Nome do método")
print("  self                     → Referência à instância")
print("  silver_key: str          → Parâmetro com tipo (string)")
print("  -> str                   → Retorna uma string")
print()
print("O QUE FAZ:")
print("  ✓ Este é um HOOK (gancho) do pipeline")
print("  ✓ O sistema chama automaticamente")
print("  ✓ Recebe o caminho S3 do arquivo Silver")
print("  ✓ Retorna o caminho após processar")
print()
print("FLUXO DO PIPELINE:")
print()
print("  Bronze (dados brutos)")
print("    ↓")
print("  Silver (processados)")
print("    ↓")
print("  [AQUI: silver_layer_transform()] ← Este método")
print("    ↓")
print("  Gold (prontos para negócio)")
print()
print("EXEMPLO DE CHAMADA:")
print("  validador = MeuValidador()")
print("  result = validador.silver_layer_transform('data/silver/clientes.parquet')")
print("  # Retorna: 'data/silver/clientes.parquet' (processado)")

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHA 37                                                          ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHA 37 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  try:")
print("      ...código aqui...")
print()
print("O QUE FAZ:")
print("  ✓ try = tenta executar o código")
print("  ✓ Se houver erro, pula para except")
print("  ✓ Se tudo OK, ignora o except")
print()
print("BENEFÍCIO:")
print("  ✅ Não deixa o programa inteiro morrer")
print("  ✅ Captura e registra erros")
print("  ✅ Permite tomada de decisão inteligente")
print()
print("FLUXO:")
print()
print("  CENÁRIO 1 (SEM ERRO):")
print("  try:")
print("    ✓ Executa linha 38-71")
print("    ✓ return silver_key (sucesso)")
print("    ✗ Ignora except")
print()
print("  CENÁRIO 2 (COM ERRO):")
print("  try:")
print("    ✗ Erro na linha 41, 50, 59, etc")
print("    ↓")
print("  except Exception as e:")
print("    ✓ Captura o erro")
print("    ✓ log.error() registra")
print("    ✓ raise relança para pipeline saber")

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHAS 41-46                                                      ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHAS 41-46 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  local_file = self.hook.download_file(")
print("      key=silver_key,")
print("      bucket_name=self.bucket,")
print("      local_path=self.tmpdir,")
print("      preserve_file_name=True")
print("  )")
print()
print("O QUE FAZ:")
print("  ✓ Faz download do arquivo de S3")
print("  ✓ Salva em diretório temporário local")
print("  ✓ Retorna o caminho local do arquivo")
print()
print("PARÂMETROS:")
print("  key=silver_key")
print("      → Caminho no S3: 'data/silver/clientes.parquet'")
print()
print("  bucket_name=self.bucket")
print("      → Nome do bucket: 'meu-datalake'")
print()
print("  local_path=self.tmpdir")
print("      → Pasta local: '/tmp/datalake_12345/'")
print()
print("  preserve_file_name=True")
print("      → Manter nome original do arquivo")
print()
print("RESULTADO:")
print("  local_file = '/tmp/datalake_12345/clientes.parquet'")
print()
print("FLUXO:")
print("  S3://meu-datalake/data/silver/clientes.parquet")
print("           ↓ (download)")
print("  /tmp/datalake_12345/clientes.parquet")

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHA 50                                                           ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHA 50 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  df = pd.read_parquet(local_file)")
print()
print("O QUE FAZ:")
print("  ✓ Lê arquivo Parquet local")
print("  ✓ Carrega em memória como DataFrame")
print("  ✓ df agora é uma tabela de dados em Python")
print()
print("RESULTADO (exemplo):")
print()
print("  Arquivo: clientes.parquet")
print("           ↓")
print("  df = ")
print("  ┌──────┬─────────────┬──────────────────┬───────────────────┐")
print("  │ id   │ nome        │ email            │ billingpostalcode │")
print("  ├──────┼─────────────┼──────────────────┼───────────────────┤")
print("  │ 1    │ João Silva  │ joao@example.com │ 12345-678         │")
print("  │ 2    │ Maria J     │ maria@example.co │ None              │")
print("  │ 3    │ Carlos O.   │ carlos@example.. │ 87654-321         │")
print("  └──────┴─────────────┴──────────────────┴───────────────────┘")
print()
print("AGORA PODE:")
print("  len(df)           → 3 (número de linhas)")
print("  df.columns        → lista de nomes de colunas")
print("  df['nome']        → acessar coluna específica")
print("  df.loc[0, 'id']   → acessar célula específica")
# Out:
# ...
# 📍 LINHA 50 DO ARQUIVO meu_validador.py
# ...
#
# CÓDIGO ORIGINAL:
#   df = pd.read_parquet(local_file)
#
# O QUE FAZ:
#   ✓ Lê arquivo Parquet local
#   ✓ Carrega em memória como DataFrame
#   ✓ df agora é uma tabela de dados em Python
#
# RESULTADO (exemplo):
#
#   Arquivo: clientes.parquet
#            ↓
#   df =
#   ┌──────┬─────────────┬──────────────────┬───────────────────┐
#   │ id   │ nome        │ email            │ billingpostalcode │
#   ├──────┼─────────────┼──────────────────┼───────────────────┤
#   │ 1    │ João Silva  │ joao@example.com │ 12345-678         │
#   │ 2    │ Maria J     │ maria@example.co │ None              │
#   │ 3    │ Carlos O.   │ carlos@example.. │ 87654-321         │
#   └──────┴─────────────┴──────────────────┴───────────────────┘
#
# AGORA PODE:
#   len(df)           → 3 (número de linhas)
#   df.columns        → lista de nomes de colunas
#   df['nome']        → acessar coluna específica
#   df.loc[0, 'id']   → acessar célula específica

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHAS 51-53                                                      ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHAS 51-53 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  original_rows = len(df)")
print("  original_cols = len(df.columns)")
print("  log.info(f'📊 [MeuValidador] Entrada: {original_rows} registros, {original_cols} colunas')")
print()
print("O QUE FAZ:")
print("  ✓ Conta número de linhas: len(df)")
print("  ✓ Conta número de colunas: len(df.columns)")
print("  ✓ Armazena para comparação depois")
print("  ✓ Registra no log")
print()
print("EXEMPLO:")
print("  df tem 1000 linhas e 15 colunas")
print("  original_rows = 1000")
print("  original_cols = 15")
print()
print("  LOG GERADO:")
print("  INFO - 📊 [MeuValidador] Entrada: 1000 registros, 15 colunas")
print()
print("PROPÓSITO:")
print("  ✅ Auditoria (saber o que entrou)")
print("  ✅ Comparar depois (antes → depois)")
print("  ✅ Rastreamento de execução")

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHA 56                                                           ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHA 56 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  df = self._apply_validations(df)")
print()
print("O QUE FAZ:")
print("  ✓ Chama o método _apply_validations() da PRÓPRIA CLASSE")
print("  ✓ Passa o DataFrame como parâmetro")
print("  ✓ Recebe o DataFrame processado de volta")
print("  ✓ df é sobrescrito com o resultado")
print()
print("ESCLARECIMENTO:")
print()
print("  MeuValidador (esta classe)")
print("  ├─ silver_layer_transform()  ← você está AQUI (linha 56)")
print("  │  └─ chama self._apply_validations()")
print("  │                    ↓")
print("  └─ _apply_validations()      ← definido na linha 76 DESTA classe")
print()
print("  RawToMedallionPipeline (superclasse)")
print("  └─ NÃO tem _apply_validations()")
print()
print("FLUXO:")
print()
print("  df (1000 registros, 15 colunas)")
print("           ↓")
print("  self._apply_validations(df)  [linha 56 chama linha 76]")
print("           ↓")
print("  [DENTRO: Executa 5 validações - linhas 76-142]")
print("           ↓")
print("  df (retornado: 995 registros, 10 colunas)")
print()
print("OPERAÇÕES DENTRO DE _apply_validations (DEFINIDO NESTA CLASSE):")
print("  1. Valida CEP")
print("  2. Remove colunas 100% nulas")
print("  3. Normaliza nomes de colunas")
print("  4. Calcula Data Quality Score")
print("  5. Registra resumo")
# Out:
# ...
# 📍 LINHA 56 DO ARQUIVO meu_validador.py
# ...
#
# CÓDIGO ORIGINAL:
#   df = self._apply_validations(df)
#
# O QUE FAZ:
#   ✓ Chama o método _apply_validations() da PRÓPRIA CLASSE
#   ✓ Passa o DataFrame como parâmetro
#   ✓ Recebe o DataFrame processado de volta
#   ✓ df é sobrescrito com o resultado
#
# ESCLARECIMENTO:
#
#   MeuValidador (esta classe)
#   ├─ silver_layer_transform()  ← você está AQUI (linha 56)
#   │  └─ chama self._apply_validations()
#   │                    ↓
#   └─ _apply_validations()      ← definido na linha 76 DESTA classe
#
#   RawToMedallionPipeline (superclasse)
#   └─ NÃO tem _apply_validations()
#
# FLUXO:
#
#   df (1000 registros, 15 colunas)
#            ↓
#   self._apply_validations(df)  [linha 56 chama linha 76]
#            ↓
#   [DENTRO: Executa 5 validações - linhas 76-142]
#            ↓
#   df (retornado: 995 registros, 10 colunas)
#
# OPERAÇÕES DENTRO DE _apply_validations (DEFINIDO NESTA CLASSE):
#   1. Valida CEP
#   2. Remove colunas 100% nulas
# ...

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHA 59                                                           ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHA 59 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  df.to_parquet(local_file, index=False)")
print()
print("O QUE FAZ:")
print("  ✓ Salva o DataFrame processado em arquivo Parquet")
print("  ✓ Sobrescreve o arquivo local original")
print("  ✓ index=False = não inclui índice do pandas")
print()
print("FLUXO:")
print()
print("  ANTES:")
print("  /tmp/datalake_12345/clientes.parquet")
print("  (1000 registros, 15 colunas)")
print()
print("  df.to_parquet(...) executa")
print("           ↓")
print()
print("  DEPOIS:")
print("  /tmp/datalake_12345/clientes.parquet")
print("  (995 registros, 10 colunas - PROCESSADO)")
print()
print("PARÂMETRO index=False:")
print("  ✓ Reduz tamanho do arquivo")
print("  ✓ Mantém apenas colunas originais")
print("  ✓ Evita metadados desnecessários")

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHAS 62-67                                                      ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHAS 62-67 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  self.hook.load_file(")
print("      filename=local_file,")
print("      key=silver_key,")
print("      bucket_name=self.bucket,")
print("      replace=True")
print("  )")
print()
print("O QUE FAZ:")
print("  ✓ Faz upload do arquivo processado de volta para S3")
print("  ✓ Sobrescreve o arquivo original")
print("  ✓ replace=True permite sobrescrever")
print()
print("PARÂMETROS:")
print()
print("  filename=local_file")
print("      → Arquivo local: '/tmp/datalake_12345/clientes.parquet'")
print()
print("  key=silver_key")
print("      → Caminho S3: 'data/silver/clientes.parquet'")
print()
print("  bucket_name=self.bucket")
print("      → Bucket: 'meu-datalake'")
print()
print("  replace=True")
print("      → Permite sobrescrever arquivo existente")
print()
print("FLUXO:")
print("  /tmp/datalake_12345/clientes.parquet")
print("           ↓ (upload)")
print("  S3://meu-datalake/data/silver/clientes.parquet (ATUALIZADO)")

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHAS 72-74                                                      ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHAS 72-74 DO ARQUIVO meu_validador.py")
print("="*80)
print()
print("CÓDIGO ORIGINAL:")
print("  except Exception as e:")
print("      log.error(f'❌ [MeuValidador] ERRO: {e}', exc_info=True)")
print("      raise")
print()
print("O QUE FAZ:")
print("  ✓ Captura QUALQUER exceção que ocorra no bloco try")
print("  ✓ e = objeto da exceção (erro)")
print("  ✓ Registra em log com detalhes")
print("  ✓ raise = relança a exceção")
print()
print("FLUXO DE ERRO:")
print()
print("  try:")
print("      linha 41: self.hook.download_file() ← ERRO AQUI")
print("      (arquivo não existe em S3)")
print("           ↓")
print("  except Exception as e:")
print("      e = FileNotFoundError(...)")
print("      log.error(❌ [MeuValidador] ERRO: [Errno 2] No such file...)")
print("      raise ← relança o erro para a classe pai")
print()
print("BENEFÍCIO:")
print("  ✅ Log detalhado (exc_info=True inclui stack trace)")
print("  ✅ Classe pai sabe que algo falhou")
print("  ✅ Pipeline não continua como se fosse sucesso")
print("  ✅ Mais fácil debugar")

# %% [markdown]
# ---
# ## ✅ SEÇÃO 4: VALIDAÇÕES INTERNAS (Método _apply_validations - Linha 76)
#
# ⚠️ **IMPORTANTE**: `_apply_validations()` é um método **DESTA classe** (MeuValidador), NÃO da superclasse!
#
# As cinco validações aplicadas ao DataFrame.

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ LINHA 75 - VALIDAÇÃO 1: CEP                                       ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHAS 85-102: VALIDAÇÃO 1 - CEP (Billing Postal Code)")
print("="*80)
print()
print("CÓDIGO:")
print("  if 'billingpostalcode' in df.columns:")
print("      invalid_mask = (")
print("          (df['billingpostalcode'].isnull()) |")
print("          (df['billingpostalcode'].astype(str).str.strip().str.lower()")
print("           .isin(['nan', 'none', 'null', '', 'undefined']))")
print("      )")
print("      invalid_count = invalid_mask.sum()")
print()
print("O QUE FAZ:")
print("  ✓ Verifica se coluna 'billingpostalcode' existe")
print("  ✓ Encontra valores inválidos (None, 'nan', 'null', etc)")
print("  ✓ Cria máscara booleana (True=inválido, False=válido)")
print("  ✓ Conta quantos inválidos")
print()
print("EXEMPLO:")
print()
print("  ENTRADA:")
print("  ┌────┬───────────────────┐")
print("  │ id │ billingpostalcode │")
print("  ├────┼───────────────────┤")
print("  │ 1  │ 12345-678         │")
print("  │ 2  │ None              │")
print("  │ 3  │ 'nan'             │")
print("  │ 4  │ ''                │")
print("  │ 5  │ 87654-321         │")
print("  └────┴───────────────────┘")
print()
print("  invalid_mask = [False, True, True, True, False]")
print("  invalid_count = 3")
print()
print("AÇÃO:")
print("  df.loc[invalid_mask, 'billingpostalcode'] = None")
print()
print("  DEPOIS:")
print("  ┌────┬───────────────────┐")
print("  │ id │ billingpostalcode │")
print("  ├────┼───────────────────┤")
print("  │ 1  │ 12345-678         │")
print("  │ 2  │ None   (NORMALIZADO)")
print("  │ 3  │ None   (era 'nan')")
print("  │ 4  │ None   (era '')")
print("  │ 5  │ 87654-321         │")
print("  └────┴───────────────────┘")

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ VALIDAÇÃO 2: REMOVER COLUNAS 100% NULAS                           ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHAS 105-110: VALIDAÇÃO 2 - Remover Colunas 100% Nulas")
print("="*80)
print()
print("CÓDIGO:")
print("  cols_to_drop = [col for col in df.columns if df[col].isnull().all()]")
print()
print("  if cols_to_drop:")
print("      log.info(f'🗑️ Removendo {len(cols_to_drop)} colunas 100% nulas')")
print("      df = df.drop(columns=cols_to_drop)")
print()
print("O QUE FAZ:")
print("  ✓ Identifica colunas que têm TUDO None/NaN")
print("  ✓ Remove essas colunas inúteis")
print("  ✓ Reduz tamanho e complexidade")
print()
print("EXEMPLO:")
print()
print("  ENTRADA (5 colunas):")
print("  ┌────┬────────┬──────────┬──────────┬──────────┐")
print("  │ id │ nome   │ email    │ telefone │ icone    │")
print("  ├────┼────────┼──────────┼──────────┼──────────┤")
print("  │ 1  │ João   │ j@ex.com │ None     │ None     │")
print("  │ 2  │ Maria  │ m@ex.com │ None     │ None     │")
print("  │ 3  │ Carlos │ c@ex.com │ None     │ None     │")
print("  └────┴────────┴──────────┴──────────┴──────────┘")
print()
print("  Análise:")
print("  - 'id': tem valores → MANTER")
print("  - 'nome': tem valores → MANTER")
print("  - 'email': tem valores → MANTER")
print("  - 'telefone': TUDO None → REMOVER")
print("  - 'icone': TUDO None → REMOVER")
print()
print("  cols_to_drop = ['telefone', 'icone']")
print()
print("  SAÍDA (3 colunas):")
print("  ┌────┬────────┬──────────┐")
print("  │ id │ nome   │ email    │")
print("  ├────┼────────┼──────────┤")
print("  │ 1  │ João   │ j@ex.com │")
print("  │ 2  │ Maria  │ m@ex.com │")
print("  │ 3  │ Carlos │ c@ex.com │")
print("  └────┴────────┴──────────┘")

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ VALIDAÇÃO 3: NORMALIZAR NOMES DE COLUNAS                          ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHAS 115-119: VALIDAÇÃO 3 - Normalizar Nomes de Colunas")
print("="*80)
print()
print("CÓDIGO:")
print("  df.columns = (df.columns")
print("               .str.strip()")
print("               .str.lower()")
print("               .str.replace(' ', '_')")
print("               .str.replace('-', '_'))")
print()
print("O QUE FAZ:")
print("  ✓ Padroniza nomes de colunas")
print("  ✓ Aplica transformações em cadeia")
print()
print("TRANSFORMAÇÕES (ORDEM):")
print()
print("  1️⃣ .str.strip()")
print("     Remove espaços início/fim")
print("     ' Customer Name ' → 'Customer Name'")
print()
print("  2️⃣ .str.lower()")
print("     Converte para minúsculas")
print("     'Customer Name' → 'customer name'")
print()
print("  3️⃣ .str.replace(' ', '_')")
print("     Substitui espaço por underscore")
print("     'customer name' → 'customer_name'")
print()
print("  4️⃣ .str.replace('-', '_')")
print("     Substitui hífen por underscore")
print("     'email-address' → 'email_address'")
print()
print("EXEMPLO COMPLETO:")
print()
print("  ENTRADA:")
print("  ['Customer Name', ' Billing Postal Code ', 'Email-Address']")
print()
print("  Após strip:")
print("  ['Customer Name', 'Billing Postal Code', 'Email-Address']")
print()
print("  Após lower:")
print("  ['customer name', 'billing postal code', 'email-address']")
print()
print("  Após replace(' '):")
print("  ['customer_name', 'billing_postal_code', 'email-address']")
print()
print("  Após replace('-'):")
print("  ['customer_name', 'billing_postal_code', 'email_address'] ✅")
print()
print("BENEFÍCIO:")
print("  ✅ Padrão consistente em todos os datasets")
print("  ✅ Evita erros ao acessar colunas")
print("  ✅ Facilita análises e queries")

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ VALIDAÇÃO 4: DATA QUALITY SCORE                                   ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHAS 122-135: VALIDAÇÃO 4 - Data Quality Score")
print("="*80)
print()
print("CÓDIGO:")
print("  total_cells = df.size")
print("  filled_cells = df.notna().sum().sum()")
print("  quality_score = (filled_cells / total_cells * 100) if total_cells > 0 else 100")
print()
print("  if quality_score < 50:")
print("      log.error(f'❌ Quality Score crítico ({quality_score:.2f}%)')")
print("  elif quality_score < 80:")
print("      log.warning(f'⚠️ Quality Score baixo ({quality_score:.2f}%)')")
print("  else:")
print("      log.info(f'✅ Quality Score aceitável')")
print()
print("O QUE FAZ:")
print("  ✓ Calcula % de células preenchidas")
print("  ✓ Métrica de qualidade dos dados")
print("  ✓ Gera alertas baseado no score")
print()
print("CÁLCULO:")
print()
print("  1. total_cells = df.size")
print("     (número total de células = linhas × colunas)")
print()
print("  2. filled_cells = df.notna().sum().sum()")
print("     (contar células COM dados)")
print()
print("  3. quality_score = (filled_cells / total_cells) × 100%")
print()
print("EXEMPLO:")
print()
print("  DataFrame: 100 linhas × 10 colunas")
print("  total_cells = 1000")
print()
print("  Células preenchidas: 889")
print("  Células nulas: 111")
print("  filled_cells = 889")
print()
print("  quality_score = (889 / 1000) × 100 = 88.9%")
print()
print("INTERPRETAÇÃO:")
print()
print("  100% ────────────────► Perfeito ✅")
print("   80% ────────────────► Aceitável ✅")
print("   50% ────────────────► Comprometido ⚠️")
print("    0% ────────────────► Muito ruim ❌")
print()
print("  Seu score 88.9% → Aceitável ✅")

# %%
# ╔════════════════════════════════════════════════════════════════════╗
# ║ VALIDAÇÃO 5: RESUMO FINAL                                         ║
# ╚════════════════════════════════════════════════════════════════════╝

print("\n" + "="*80)
print("📍 LINHAS 140-142: VALIDAÇÃO 5 - Resumo Final")
print("="*80)
print()
print("CÓDIGO:")
print("  log.info(f'📈 Resumo: {original_rows}→{len(df)} registros, {original_cols}→{len(df.columns)} colunas, {quality_score:.2f}% qualidade ✅')")
print()
print("  return df")
print()
print("O QUE FAZ:")
print("  ✓ Registra resumo antes → depois")
print("  ✓ Retorna DataFrame processado")
print()
print("EXEMPLO DE SAÍDA:")
print()
print("  ENTRADA:  1000 registros, 15 colunas")
print("            8 colunas 100% nulas")
print("            Alguns CEP inválidos")
print()
print("  PROCESSAMENTO (apply_validations)")
print("            ↓")
print()
print("  SAÍDA:    995 registros, 7 colunas")
print("            CEP normalizado")
print("            Colunas nulas removidas")
print("            Nomes padronizados")
print()
print("  LOG:")
print("  📈 Resumo: 1000→995 registros, 15→7 colunas, 88.89% qualidade ✅")
print()
print("BENEFÍCIO:")
print("  ✅ Auditoria completa (saber exatamente o que foi feito)")
print("  ✅ Rastreamento (logs para debugging)")
print("  ✅ Confirmação (✅ indica sucesso)")

# %% [markdown]
# ---
# ## 🎯 Resumo Completo do Script
#
# Agora que passou por cada linha individualmente, aqui está o fluxo completo:

# %%
fluxo_completo = """
╔════════════════════════════════════════════════════════════════════════════════╗
║               FLUXO COMPLETO: meu_validador.py (LINHA POR LINHA)              ║
╚════════════════════════════════════════════════════════════════════════════════╝

┌─ IMPORTAÇÕES (Linhas 11-16) ──────────────────────────────────────────────────┐
│                                                                                │
│  from lib.medallion_pipeline_v2 import RawToMedallionPipeline  (Linha 11)     │
│  import pandas as pd                                           (Linha 12)     │
│  import logging                                               (Linha 13)     │
│  log = logging.getLogger(__name__)                            (Linha 16)     │
│                                                                                │
└────────────────────────────────────────────────────────────────────────────────┘
              ↓
┌─ CLASSE (Linha 19) ───────────────────────────────────────────────────────────┐
│                                                                                │
│  class MeuValidador(RawToMedallionPipeline):                                   │
│      │                                                                         │
│      └─→ Herda: self.hook, self.bucket, self.tmpdir                           │
│                                                                                │
└────────────────────────────────────────────────────────────────────────────────┘
              ↓
┌─ MÉTODO PRINCIPAL (Linhas 31-71) ─────────────────────────────────────────────┐
│                                                                                │
│  def silver_layer_transform(self, silver_key: str) -> str:                    │
│                                                                                │
│      try:                                                    (Linha 34)       │
│          ┌─ Download (Linhas 40-46) ────────────────────┐                    │
│          │ self.hook.download_file(...)                 │                    │
│          │ → local_file = '/tmp/...clientes.parquet'    │                    │
│          └──────────────────────────────────────────────┘                    │
│                    ↓                                                          │
│          ┌─ Leitura (Linhas 51-54) ──────────────────────┐                   │
│          │ df = pd.read_parquet(local_file)             │                   │
│          │ original_rows = len(df)                      │                   │
│          │ original_cols = len(df.columns)              │                   │
│          └──────────────────────────────────────────────┘                   │
│                    ↓                                                          │
│          ┌─ Aplicar Validações (Linha 57) ──────────────┐                   │
│          │ df = self._apply_validations(df)             │                   │
│          │                                              │                   │
│          │ DENTRO: Executa 5 validações                │                   │
│          │ ✓ Valida CEP                                │                   │
│          │ ✓ Remove colunas 100% nulas                │                   │
│          │ ✓ Normaliza nomes                          │                   │
│          │ ✓ Calcula Quality Score                    │                   │
│          │ ✓ Registra resumo                          │                   │
│          └──────────────────────────────────────────────┘                   │
│                    ↓                                                          │
│          ┌─ Salvar Localmente (Linha 60) ────────────────┐                  │
│          │ df.to_parquet(local_file, index=False)       │                  │
│          │ (Sobrescreve arquivo local)                  │                  │
│          └──────────────────────────────────────────────┘                  │
│                    ↓                                                          │
│          ┌─ Upload S3 (Linhas 63-68) ────────────────────┐                  │
│          │ self.hook.load_file(...)                     │                  │
│          │ (Sobrescreve arquivo em S3)                  │                  │
│          └──────────────────────────────────────────────┘                  │
│                    ↓                                                          │
│          return silver_key ✅                         (Linha 71)            │
│                                                                              │
│      except Exception as e:                         (Linhas 72-73)         │
│          log.error(...)                                                     │
│          raise                                                              │
│                                                                              │
└────────────────────────────────────────────────────────────────────────────────┘

RESULTADO:
✅ Arquivo processado, transformado e devolvido ao S3 com sucesso!
"""

print(fluxo_completo)

# %% [markdown]
# ---
# ## 📚 Referência Rápida
#
# | Linha | Código | Descrição |
# |-------|--------|----------|
# | 11 | `from lib.medallion_pipeline_v2 import RawToMedallionPipeline` | Importa classe base |
# | 12 | `import pandas as pd` | Importa pandas |
# | 13 | `import logging` | Importa logging |
# | 16 | `log = logging.getLogger(__name__)` | Cria logger |
# | 19 | `class MeuValidador(RawToMedallionPipeline):` | Define classe |
# | 31 | `def silver_layer_transform(self, silver_key: str) -> str:` | Método principal |
# | 34 | `try:` | Início de bloco seguro |
# | 40-46 | `self.hook.download_file(...)` | Download S3 → Local |
# | 51 | `df = pd.read_parquet(local_file)` | Lê em DataFrame |
# | 52-53 | `original_rows / original_cols` | Guarda dimensões originais |
# | 57 | `df = self._apply_validations(df)` | Aplica validações |
# | 60 | `df.to_parquet(local_file, index=False)` | Salva localmente |
# | 63-68 | `self.hook.load_file(...)` | Upload Local → S3 |
# | 71 | `return silver_key` | Retorna sucesso |
# | 72-73 | `except Exception as e: ... raise` | Trata erros |
# | 85 | `if 'billingpostalcode' in df.columns:` | Validação 1 (CEP) |
# | 105 | `cols_to_drop = [col for col...]` | Validação 2 (Colunas nulas) |
# | 115-119 | `df.columns = (df.columns.str...)` | Validação 3 (Normalização) |
# | 122-135 | `quality_score = ...` | Validação 4 (Quality Score) |
# | 140 | `log.info(f'📈 Resumo:...')` | Validação 5 (Resumo) |
# | 142 | `return df` | Retorna DataFrame processado |

# %% [markdown]
# ---
# ## 🎓 Conclusão
#
# Você agora entende **cada linha** do arquivo `meu_validador.py`!
#
# ### Conceitos-Chave:
# 1. **Herança** - MeuValidador herda de RawToMedallionPipeline
# 2. **Hooks** - Método silver_layer_transform é chamado automaticamente
# 3. **Pandas** - Manipulação de DataFrames
# 4. **S3** - Download/Upload de arquivos
# 5. **Logging** - Rastreamento de execução
# 6. **Validações** - 5 tipos diferentes de limpeza de dados
# 7. **Tratamento de Erros** - Try/Except para robustez
#
# ### Próximos Passos:
# - Use este padrão para criar seus próprios validadores
# - Adapte as validações para suas regras de negócio
# - Sempre registre em log para auditoria
